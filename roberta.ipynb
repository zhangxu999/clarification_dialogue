# %%
import json
import spacy
import pandas as pd
import os
import spacy
from transformers import pipeline
import tqdm

nlp = spacy.load("en_core_web_sm")
unmasker = pipeline('fill-mask', model='xlm-roberta-base')

def load_squad(path):
    para_path = f"{path}.para.json"
    if os.path.exists(para_path):
        with open(para_path,mode='r',encoding='utf8') as fpara:
            return json.load(fpara)
    with open(path,encoding='utf8') as f:
        origin_data = json.load(f)
        paragraphs = []
        for article in origin_data['data']:
            for paragraph in article['paragraphs']:
                paragraphs.append(paragraph['context'])
    with open(para_path,'w',encoding='utf8') as fpara:
        json.dump(paragraphs,fpara)
    return paragraphs



def mask_paragraph(paragraph):
    def post_process_mask(output_mask,idx):
        all_masks = []
        for mask in output_mask:
            nlp_seq = nlp(mask['sequence'])
            mask['lemma'] = mask['token_str']
            for token in nlp_seq:
                if token.text == mask['token_str']:
                    mask['lemma'] = token.lemma_
            mask['score'] = round(mask['score'],4)
            mask.pop('sequence')
            all_masks.append(mask)
        return all_masks
    mask_sentences = []
    sentences = list(nlp(paragraph).sents)
    for idx_sen, sen in enumerate(sentences):
        sen_item = {'sentence':sen.text}
        sen_item['mask'] = []
        for i,token in enumerate(nlp(sen.text)):
            if token.pos_=='NOUN':
                masked_sentence = f"{sen.text[:token.idx]}<mask>{sen.text[token.idx+len(token):]}"
                # masked_paragraph = f'{"".join([s.text for s in sentences[:idx_sen]])}{masked_sentence}{"".join([s.text for s in sentences[idx_sen+1:]])}'
                output_mask = unmasker(masked_sentence,top_k=10)
                output_mask = post_process_mask(output_mask,i)
                mask_item = dict(mask_word=token.text, lemma_word=token.lemma_, masked_sentence=masked_sentence, output_mask=output_mask)
                sen_item['mask'].append(mask_item)
        mask_sentences.append(sen_item)
    return mask_sentences

# %%
save_path = "../data/SQuAD/mask"
paragraphs = load_squad("../data/SQuAD/train-v2.0.json")

mask_sentences = []
cnt = 0
for i,para in tqdm.tqdm(enumerate(paragraphs)):
    cnt += 1
    try:
        m_sentence = mask_paragraph(para)
        mask_sentences.append(m_sentence)
    except Exception as e:
        print(cnt,e)
        print(para)
    if cnt%100==0 :
        with open(f"{save_path}/mask_{cnt}.json","w",encoding="utf8") as f:
            json.dump(mask_sentences,f)
        mask_sentences = []
if len(mask_sentences)!=0:
    with open(f"{save_path}/mask_{cnt}.json","w",encoding="utf8") as f:
        json.dump(mask_sentences,f)
# Out:
# 6068it [8:27:33,  5.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [310], in <cell line: 6>()
#       7 cnt += 1
#       8 try:
# ----> 9     m_sentence = mask_paragraph(para)
#      10     mask_sentences.append(m_sentence)
#      11 except Exception as e:
#
# Input In [309], in mask_paragraph(paragraph)
#      49 masked_sentence = f"{sen.text[:token.idx]}<mask>{sen.text[token.idx+len(token):]}"
#      50 # masked_paragraph = f'{"".join([s.text for s in sentences[:idx_sen]])}{masked_sentence}{"".join([s.text for s in sentences[idx_sen+1:]])}'
# ---> 51 output_mask = unmasker(masked_sentence,top_k=10)
#      52 output_mask = post_process_mask(output_mask,i)
#      53 mask_item = dict(mask_word=token.text, lemma_word=token.lemma_, masked_sentence=masked_sentence, output_mask=output_mask)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/fill_mask.py:239, in FillMaskPipeline.__call__(self, inputs, *args, **kwargs)
#     217 def __call__(self, inputs, *args, **kwargs):
#     218     """
#     219     Fill the masked token in the text(s) given as inputs.
#     220
#    (...)
#     237         - **token** (`str`) -- The predicted token (to replace the masked one).
#     238     """
# --> 239     outputs = super().__call__(inputs, **kwargs)
#     240     if isinstance(inputs, list) and len(inputs) == 1:
#     241         return outputs[0]
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1109, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1101     return next(
#    1102         iter(
#    1103             self.get_iterator(
#    (...)
#    1106         )
#    1107     )
#    1108 else:
# -> 1109     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1116, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1114 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1115     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1116     model_outputs = self.forward(model_inputs, **forward_params)
#    1117     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1118     return outputs
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1015, in Pipeline.forward(self, model_inputs, **forward_params)
#    1013     with inference_context():
#    1014         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1015         model_outputs = self._forward(model_inputs, **forward_params)
#    1016         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1017 else:
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/fill_mask.py:101, in FillMaskPipeline._forward(self, model_inputs)
#     100 def _forward(self, model_inputs):
# --> 101     model_outputs = self.model(**model_inputs)
#     102     model_outputs["input_ids"] = model_inputs["input_ids"]
#     103     return model_outputs
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:1120, in XLMRobertaForMaskedLM.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, output_attentions, output_hidden_states, return_dict)
#    1106 outputs = self.roberta(
#    1107     input_ids,
#    1108     attention_mask=attention_mask,
#    (...)
#    1117     return_dict=return_dict,
#    1118 )
#    1119 sequence_output = outputs[0]
# -> 1120 prediction_scores = self.lm_head(sequence_output)
#    1122 masked_lm_loss = None
#    1123 if labels is not None:
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:1158, in XLMRobertaLMHead.forward(self, features, **kwargs)
#    1155 x = self.layer_norm(x)
#    1157 # project back to size of vocabulary with bias
# -> 1158 x = self.decoder(x)
#    1160 return x
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
mask_sentences
# Out:
# [[{'sentence': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress.',
#    'mask': [{'mask_word': 'singer',
#      'lemma_word': 'singer',
#      'masked_sentence': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American <mask>, songwriter, record producer and actress.',
#      'output_mask': [{'score': 0.245,
#        'token': 39329,
#        'token_str': 'actor',
#        'lemma': 'actor'},
#       {'score': 0.185, 'token': 5367, 'token_str': 'sing', 'lemma': 'sing'},
#       {'score': 0.1265, 'token': 3299, 'token_str': 'model', 'lemma': 'model'},
#       {'score': 0.1152,
#        'token': 215542,
#        'token_str': 'actress',
#        'lemma': 'actress'},
#       {'score': 0.068, 'token': 19612, 'token_str': 'music', 'lemma': 'music'},
#       {'score': 0.0319, 'token': 1346, 'token_str': 'film', 'lemma': 'film'},
#       {'score': 0.0319,
#        'token': 108558,
#        'token_str': 'producer',
#        'lemma': 'producer'},
#       {'score': 0.0257,
#        'token': 83358,
#        'token_str': 'Singer',
#        'lemma': 'Singer'},
#       {'score': 0.0232, 'token': 7426, 'token_str': 'pop', 'lemma': 'pop'},
#       {'score': 0.0182,
#        'token': 42179,
#        'token_str': 'author',
#        'lemma': 'author'}]},
#     {'mask_word': 'songwriter',
#      'lemma_word': 'songwriter',
#      'masked_sentence': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, <mask>, record producer and actress.',
#      'output_mask': [{'score': 0.5329,
#        'token': 39329,
#        'token_str': 'actor',
#        'lemma': 'actor'},
#       {'score': 0.121,
#        'token': 215542,
#        'token_str': 'actress',
#        'lemma': 'actress'},
#       {'score': 0.0955, 'token': 3299, 'token_str': 'model', 'lemma': 'model'},
#       {'score': 0.0939,
#        'token': 108558,
#        'token_str': 'producer',
#        'lemma': 'producer'},
#       {'score': 0.0521, 'token': 22828, 'token_str': 'DJ', 'lemma': 'DJ'},
#       {'score': 0.0259,
#        'token': 14364,
#        'token_str': 'director',
#        'lemma': 'director'},
#       {'score': 0.0081,
#        'token': 22104,
#        'token_str': 'artist',
#        'lemma': 'artist'},
#       {'score': 0.0069,
#        'token': 42179,
#        'token_str': 'author',
#        'lemma': 'author'},
#       {'score': 0.0058,
#        'token': 139356,
#        'token_str': 'pianist',
#        'lemma': 'pianist'},
#       {'score': 0.0058, 'token': 6057, 'token_str': 'star', 'lemma': 'star'}]},
#     {'mask_word': 'record',
#      'lemma_word': 'record',
#      'masked_sentence': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, <mask> producer and actress.',
#      'output_mask': [{'score': 0.3103,
#        'token': 1346,
#        'token_str': 'film',
#        'lemma': 'film'},
#       {'score': 0.2502,
#        'token': 159354,
#        'token_str': 'executive',
#        'lemma': 'executive'},
#       {'score': 0.1623,
#        'token': 113976,
#        'token_str': 'television',
#        'lemma': 'television'},
#       {'score': 0.0959,
#        'token': 17164,
#        'token_str': 'record',
#        'lemma': 'record'},
#       {'score': 0.0754,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0215,
#        'token': 14277,
#        'token_str': 'movie',
#        'lemma': 'movie'},
#       {'score': 0.0181, 'token': 1202, 'token_str': 'video', 'lemma': 'video'},
#       {'score': 0.0159, 'token': 1910, 'token_str': 'TV', 'lemma': 'tv'},
#       {'score': 0.008, 'token': 136, 'token_str': 'and', 'lemma': 'and'},
#       {'score': 0.0042,
#        'token': 5977,
#        'token_str': 'radio',
#        'lemma': 'radio'}]},
#     {'mask_word': 'producer',
#      'lemma_word': 'producer',
#      'masked_sentence': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record <mask> and actress.',
#      'output_mask': [{'score': 0.7557,
#        'token': 108558,
#        'token_str': 'producer',
#        'lemma': 'producer'},
#       {'score': 0.2075, 'token': 56, 'token_str': 'er', 'lemma': 'and'},
#       {'score': 0.015, 'token': 67967, 'token_str': 'label', 'lemma': 'label'},
#       {'score': 0.0041,
#        'token': 22104,
#        'token_str': 'artist',
#        'lemma': 'artist'},
#       {'score': 0.0037,
#        'token': 17164,
#        'token_str': 'record',
#        'lemma': 'record'},
#       {'score': 0.0023,
#        'token': 58585,
#        'token_str': 'player',
#        'lemma': 'player'},
#       {'score': 0.0019,
#        'token': 14380,
#        'token_str': 'company',
#        'lemma': 'company'},
#       {'score': 0.0017, 'token': 55474, 'token_str': 'maker', 'lemma': 'and'},
#       {'score': 0.0017, 'token': 6057, 'token_str': 'star', 'lemma': 'star'},
#       {'score': 0.0012,
#        'token': 70035,
#        'token_str': 'writer',
#        'lemma': 'and'}]},
#     {'mask_word': 'actress',
#      'lemma_word': 'actress',
#      'masked_sentence': 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and <mask>.',
#      'output_mask': [{'score': 0.1708,
#        'token': 215542,
#        'token_str': 'actress',
#        'lemma': 'actress'},
#       {'score': 0.1191,
#        'token': 108558,
#        'token_str': 'producer',
#        'lemma': 'producer'},
#       {'score': 0.0915,
#        'token': 14364,
#        'token_str': 'director',
#        'lemma': 'director'},
#       {'score': 0.0705, 'token': 22828, 'token_str': 'DJ', 'lemma': 'DJ'},
#       {'score': 0.0393,
#        'token': 39329,
#        'token_str': 'actor',
#        'lemma': 'actor'},
#       {'score': 0.0323,
#        'token': 113976,
#        'token_str': 'television',
#        'lemma': 'television'},
#       {'score': 0.0299,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0279,
#        'token': 22104,
#        'token_str': 'artist',
#        'lemma': 'artist'},
#       {'score': 0.024, 'token': 10, 'token_str': 'a', 'lemma': 'a.'},
#       {'score': 0.0154,
#        'token': 42179,
#        'token_str': 'author',
#        'lemma': 'author'}]}]},
#   {'sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#    'mask': [{'mask_word': 'singing',
#      'lemma_word': 'singing',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various <mask> and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.7486,
#        'token': 82393,
#        'token_str': 'dance',
#        'lemma': 'dance'},
#       {'score': 0.053, 'token': 19612, 'token_str': 'music', 'lemma': 'music'},
#       {'score': 0.0315,
#        'token': 24668,
#        'token_str': 'musical',
#        'lemma': 'musical'},
#       {'score': 0.021,
#        'token': 180327,
#        'token_str': 'comedy',
#        'lemma': 'comedy'},
#       {'score': 0.0129,
#        'token': 16569,
#        'token_str': 'piano',
#        'lemma': 'piano'},
#       {'score': 0.0123,
#        'token': 36541,
#        'token_str': 'stage',
#        'lemma': 'stage'},
#       {'score': 0.0119, 'token': 81693, 'token_str': 'arts', 'lemma': 'art'},
#       {'score': 0.006, 'token': 23134, 'token_str': 'drama', 'lemma': 'drama'},
#       {'score': 0.0046,
#        'token': 145597,
#        'token_str': 'karaoke',
#        'lemma': 'karaoke'},
#       {'score': 0.0041,
#        'token': 13950,
#        'token_str': 'rock',
#        'lemma': 'rock'}]},
#     {'mask_word': 'dancing',
#      'lemma_word': 'dancing',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and <mask> competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.5853,
#        'token': 82393,
#        'token_str': 'dance',
#        'lemma': 'dance'},
#       {'score': 0.0356,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0337,
#        'token': 23718,
#        'token_str': 'performance',
#        'lemma': 'performance'},
#       {'score': 0.0289,
#        'token': 32562,
#        'token_str': 'writing',
#        'lemma': 'writing'},
#       {'score': 0.0262,
#        'token': 108171,
#        'token_str': 'vocal',
#        'lemma': 'vocal'},
#       {'score': 0.0258, 'token': 47617, 'token_str': 'drum', 'lemma': 'drum'},
#       {'score': 0.0244,
#        'token': 180327,
#        'token_str': 'comedy',
#        'lemma': 'comedy'},
#       {'score': 0.0235,
#        'token': 23134,
#        'token_str': 'drama',
#        'lemma': 'drama'},
#       {'score': 0.0164,
#        'token': 16569,
#        'token_str': 'piano',
#        'lemma': 'piano'},
#       {'score': 0.013,
#        'token': 182304,
#        'token_str': 'recording',
#        'lemma': 'recording'}]},
#     {'mask_word': 'competitions',
#      'lemma_word': 'competition',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing <mask> as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.3608,
#        'token': 94407,
#        'token_str': 'groups',
#        'lemma': 'group'},
#       {'score': 0.2271, 'token': 45831, 'token_str': 'shows', 'lemma': 'show'},
#       {'score': 0.1083,
#        'token': 115215,
#        'token_str': 'schools',
#        'lemma': 'school'},
#       {'score': 0.0822,
#        'token': 61112,
#        'token_str': 'classes',
#        'lemma': 'class'},
#       {'score': 0.0543,
#        'token': 117406,
#        'token_str': 'clubs',
#        'lemma': 'club'},
#       {'score': 0.0356,
#        'token': 103391,
#        'token_str': 'programs',
#        'lemma': 'program'},
#       {'score': 0.0289,
#        'token': 117528,
#        'token_str': 'workshops',
#        'lemma': 'workshop'},
#       {'score': 0.0219,
#        'token': 142080,
#        'token_str': 'communities',
#        'lemma': 'community'},
#       {'score': 0.0102,
#        'token': 47353,
#        'token_str': 'events',
#        'lemma': 'event'},
#       {'score': 0.008,
#        'token': 130370,
#        'token_str': 'circles',
#        'lemma': 'circle'}]},
#     {'mask_word': 'child',
#      'lemma_word': 'child',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a <mask>, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.33,
#        'token': 166513,
#        'token_str': 'teenager',
#        'lemma': 'teenager'},
#       {'score': 0.258, 'token': 29041, 'token_str': 'child', 'lemma': 'child'},
#       {'score': 0.049,
#        'token': 48807,
#        'token_str': 'junior',
#        'lemma': 'junior'},
#       {'score': 0.0415,
#        'token': 9836,
#        'token_str': 'student',
#        'lemma': 'student'},
#       {'score': 0.0377, 'token': 3299, 'token_str': 'model', 'lemma': 'model'},
#       {'score': 0.029, 'token': 7003, 'token_str': 'teen', 'lemma': 'teen'},
#       {'score': 0.0268, 'token': 23040, 'token_str': 'girl', 'lemma': 'girl'},
#       {'score': 0.0251,
#        'token': 22962,
#        'token_str': 'senior',
#        'lemma': 'senior'},
#       {'score': 0.0156, 'token': 8753, 'token_str': 'band', 'lemma': 'band'},
#       {'score': 0.0136,
#        'token': 76849,
#        'token_str': 'daughter',
#        'lemma': 'daughter'}]},
#     {'mask_word': 'fame',
#      'lemma_word': 'fame',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to <mask> in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.9776,
#        'token': 65536,
#        'token_str': 'fame',
#        'lemma': 'fame'},
#       {'score': 0.0064,
#        'token': 51339,
#        'token_str': 'perform',
#        'lemma': 'perform'},
#       {'score': 0.0038, 'token': 6897, 'token_str': 'life', 'lemma': 'life'},
#       {'score': 0.0017,
#        'token': 38436,
#        'token_str': 'Hollywood',
#        'lemma': 'Hollywood'},
#       {'score': 0.0015, 'token': 6057, 'token_str': 'star', 'lemma': 'star'},
#       {'score': 0.0013,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0007,
#        'token': 14537,
#        'token_str': 'power',
#        'lemma': 'power'},
#       {'score': 0.0005, 'token': 11192, 'token_str': 'high', 'lemma': 'high'},
#       {'score': 0.0004, 'token': 11301, 'token_str': 'play', 'lemma': 'play'},
#       {'score': 0.0003,
#        'token': 36272,
#        'token_str': 'success',
#        'lemma': 'success'}]},
#     {'mask_word': '1990s',
#      'lemma_word': '1990',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late <mask> as lead singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.183,
#        'token': 15643,
#        'token_str': '1980',
#        'lemma': '1980'},
#       {'score': 0.1691, 'token': 11704, 'token_str': '1990', 'lemma': '1990'},
#       {'score': 0.1017, 'token': 19340, 'token_str': '1970', 'lemma': '1970'},
#       {'score': 0.0758, 'token': 3576, 'token_str': '2000', 'lemma': '2000'},
#       {'score': 0.074, 'token': 5369, 'token_str': 'years', 'lemma': 'year'},
#       {'score': 0.0452, 'token': 2510, 'token_str': '90', 'lemma': '90'},
#       {'score': 0.0396, 'token': 23936, 'token_str': '1960', 'lemma': '1960'},
#       {'score': 0.0286, 'token': 2248, 'token_str': '80', 'lemma': '80'},
#       {'score': 0.0269, 'token': 27631, 'token_str': '1950', 'lemma': '1950'},
#       {'score': 0.0203, 'token': 2358, 'token_str': '70', 'lemma': '70'}]},
#     {'mask_word': 'lead',
#      'lemma_word': 'lead',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as <mask> singer of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.6046,
#        'token': 37105,
#        'token_str': 'lead',
#        'lemma': 'lead'},
#       {'score': 0.2114, 'token': 70, 'token_str': 'the', 'lemma': 'the'},
#       {'score': 0.1439, 'token': 10, 'token_str': 'a', 'lemma': 'a'},
#       {'score': 0.0071,
#        'token': 121399,
#        'token_str': 'guest',
#        'lemma': 'guest'},
#       {'score': 0.0031,
#        'token': 195644,
#        'token_str': 'assistant',
#        'lemma': 'assistant'},
#       {'score': 0.002,
#        'token': 108171,
#        'token_str': 'vocal',
#        'lemma': 'vocal'},
#       {'score': 0.0018,
#        'token': 22962,
#        'token_str': 'senior',
#        'lemma': 'senior'},
#       {'score': 0.0018, 'token': 2639, 'token_str': 'solo', 'lemma': 'solo'},
#       {'score': 0.0014,
#        'token': 7893,
#        'token_str': 'principal',
#        'lemma': 'principal'},
#       {'score': 0.0014,
#        'token': 105207,
#        'token_str': 'leading',
#        'lemma': 'lead'}]},
#     {'mask_word': 'singer',
#      'lemma_word': 'singer',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead <mask> of R&B girl-group Destiny's Child.",
#      'output_mask': [{'score': 0.4758,
#        'token': 32786,
#        'token_str': 'member',
#        'lemma': 'member'},
#       {'score': 0.194,
#        'token': 108171,
#        'token_str': 'vocal',
#        'lemma': 'vocal'},
#       {'score': 0.122,
#        'token': 108558,
#        'token_str': 'producer',
#        'lemma': 'producer'},
#       {'score': 0.0576, 'token': 3299, 'token_str': 'model', 'lemma': 'model'},
#       {'score': 0.0136,
#        'token': 215542,
#        'token_str': 'actress',
#        'lemma': 'actress'},
#       {'score': 0.0132, 'token': 27992, 'token_str': 'act', 'lemma': 'act'},
#       {'score': 0.0117, 'token': 6057, 'token_str': 'star', 'lemma': 'star'},
#       {'score': 0.0102,
#        'token': 101275,
#        'token_str': 'guitar',
#        'lemma': 'guitar'},
#       {'score': 0.0072,
#        'token': 22104,
#        'token_str': 'artist',
#        'lemma': 'artist'},
#       {'score': 0.0071,
#        'token': 117776,
#        'token_str': 'female',
#        'lemma': 'female'}]},
#     {'mask_word': 'girl',
#      'lemma_word': 'girl',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B <mask>-group Destiny's Child.",
#      'output_mask': [{'score': 0.0664,
#        'token': 8753,
#        'token_str': 'band',
#        'lemma': 'band'},
#       {'score': 0.0583, 'token': 23040, 'token_str': 'girl', 'lemma': 'girl'},
#       {'score': 0.057, 'token': 5962, 'token_str': 'hit', 'lemma': 'hit'},
#       {'score': 0.0546,
#        'token': 82393,
#        'token_str': 'dance',
#        'lemma': 'dance'},
#       {'score': 0.0471, 'token': 13950, 'token_str': 'rock', 'lemma': 'rock'},
#       {'score': 0.0433,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0356, 'token': 1614, 'token_str': 'sub', 'lemma': 'sub'},
#       {'score': 0.0354, 'token': 7426, 'token_str': 'pop', 'lemma': 'pop'},
#       {'score': 0.0317, 'token': 552, 'token_str': 'co', 'lemma': 'co'},
#       {'score': 0.031,
#        'token': 102728,
#        'token_str': 'idol',
#        'lemma': 'idol'}]},
#     {'mask_word': 'group',
#      'lemma_word': 'group',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-<mask> Destiny's Child.",
#      'output_mask': [{'score': 0.8245,
#        'token': 8262,
#        'token_str': 'band',
#        'lemma': 'band'},
#       {'score': 0.0614,
#        'token': 51588,
#        'token_str': 'group',
#        'lemma': 'group'},
#       {'score': 0.0599,
#        'token': 8753,
#        'token_str': 'band',
#        'lemma': 'Destiny'},
#       {'score': 0.0074, 'token': 35821, 'token_str': 'song', 'lemma': 'song'},
#       {'score': 0.0055, 'token': 11400, 'token_str': 'hit', 'lemma': 'hit'},
#       {'score': 0.0032, 'token': 33554, 'token_str': 'pop', 'lemma': 'pop'},
#       {'score': 0.0031, 'token': 2037, 'token_str': 'up', 'lemma': 'up'},
#       {'score': 0.0026,
#        'token': 95322,
#        'token_str': 'project',
#        'lemma': 'project'},
#       {'score': 0.0026,
#        'token': 40042,
#        'token_str': 'gruppen',
#        'lemma': 'gruppen'},
#       {'score': 0.0025,
#        'token': 21115,
#        'token_str': 'group',
#        'lemma': 'Destiny'}]},
#     {'mask_word': 'Child',
#      'lemma_word': 'child',
#      'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's <mask>.",
#      'output_mask': [{'score': 0.064,
#        'token': 123829,
#        'token_str': 'Child',
#        'lemma': 'child'},
#       {'score': 0.0218, 'token': 7687, 'token_str': 'Club', 'lemma': 'Club'},
#       {'score': 0.017,
#        'token': 183672,
#        'token_str': 'Creed',
#        'lemma': 'Creed'},
#       {'score': 0.0154, 'token': 24624, 'token_str': 'Baby', 'lemma': 'Baby'},
#       {'score': 0.0139, 'token': 6661, 'token_str': 'World', 'lemma': 'world'},
#       {'score': 0.0132,
#        'token': 41945,
#        'token_str': 'Dream',
#        'lemma': 'Dream'},
#       {'score': 0.0132, 'token': 14298, 'token_str': 'Band', 'lemma': 'Band'},
#       {'score': 0.013, 'token': 67022, 'token_str': 'Dance', 'lemma': 'Dance'},
#       {'score': 0.0129, 'token': 59144, 'token_str': 'Tale', 'lemma': 'Tale'},
#       {'score': 0.0128,
#        'token': 133466,
#        'token_str': 'Paradise',
#        'lemma': 'Paradise'}]}]},
#   {'sentence': "Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time.",
#    'mask': [{'mask_word': 'father',
#      'lemma_word': 'father',
#      'masked_sentence': "Managed by her <mask>, Mathew Knowles, the group became one of the world's best-selling girl groups of all time.",
#      'output_mask': [{'score': 0.2948,
#        'token': 71390,
#        'token_str': 'husband',
#        'lemma': 'husband'},
#       {'score': 0.1737,
#        'token': 67373,
#        'token_str': 'father',
#        'lemma': 'father'},
#       {'score': 0.0724, 'token': 45733, 'token_str': 'CEO', 'lemma': 'CEO'},
#       {'score': 0.0686,
#        'token': 52114,
#        'token_str': 'mentor',
#        'lemma': 'mentor'},
#       {'score': 0.0534,
#        'token': 101785,
#        'token_str': 'owner',
#        'lemma': 'owner'},
#       {'score': 0.0443,
#        'token': 14364,
#        'token_str': 'director',
#        'lemma': 'director'},
#       {'score': 0.0395,
#        'token': 31095,
#        'token_str': 'manager',
#        'lemma': 'manager'},
#       {'score': 0.0263,
#        'token': 179505,
#        'token_str': 'creator',
#        'lemma': 'creator'},
#       {'score': 0.024,
#        'token': 57724,
#        'token_str': 'leader',
#        'lemma': 'leader'},
#       {'score': 0.0217,
#        'token': 177367,
#        'token_str': 'boyfriend',
#        'lemma': 'boyfriend'}]},
#     {'mask_word': 'group',
#      'lemma_word': 'group',
#      'masked_sentence': "Managed by her father, Mathew Knowles, the <mask> became one of the world's best-selling girl groups of all time.",
#      'output_mask': [{'score': 0.4456,
#        'token': 21115,
#        'token_str': 'group',
#        'lemma': 'group'},
#       {'score': 0.3215, 'token': 8753, 'token_str': 'band', 'lemma': 'band'},
#       {'score': 0.014, 'token': 104713, 'token_str': 'trio', 'lemma': 'trio'},
#       {'score': 0.0112, 'token': 11938, 'token_str': 'club', 'lemma': 'club'},
#       {'score': 0.0106, 'token': 34965, 'token_str': 'duo', 'lemma': 'duo'},
#       {'score': 0.0092,
#        'token': 42486,
#        'token_str': 'collection',
#        'lemma': 'collection'},
#       {'score': 0.0092, 'token': 7175, 'token_str': 'team', 'lemma': 'team'},
#       {'score': 0.0084, 'token': 80836, 'token_str': 'pair', 'lemma': 'pair'},
#       {'score': 0.0074, 'token': 29526, 'token_str': 'girls', 'lemma': 'girl'},
#       {'score': 0.0063,
#        'token': 36549,
#        'token_str': 'series',
#        'lemma': 'series'}]},
#     {'mask_word': 'world',
#      'lemma_word': 'world',
#      'masked_sentence': "Managed by her father, Mathew Knowles, the group became one of the <mask>'s best-selling girl groups of all time.",
#      'output_mask': [{'score': 0.3448,
#        'token': 17274,
#        'token_str': 'UK',
#        'lemma': 'UK'},
#       {'score': 0.1921, 'token': 8999, 'token_str': 'world', 'lemma': 'world'},
#       {'score': 0.0556, 'token': 4602, 'token_str': 'USA', 'lemma': 'USA'},
#       {'score': 0.052,
#        'token': 23295,
#        'token_str': 'country',
#        'lemma': 'country'},
#       {'score': 0.0346,
#        'token': 64857,
#        'token_str': 'nation',
#        'lemma': 'nation'},
#       {'score': 0.027, 'token': 44109, 'token_str': 'Queen', 'lemma': 'Queen'},
#       {'score': 0.0194, 'token': 6661, 'token_str': 'World', 'lemma': 'World'},
#       {'score': 0.0156, 'token': 4831, 'token_str': 'BBC', 'lemma': 'BBC'},
#       {'score': 0.0066,
#        'token': 130891,
#        'token_str': 'Britain',
#        'lemma': 'Britain'},
#       {'score': 0.0064, 'token': 7082, 'token_str': 'US', 'lemma': 'US'}]},
#     {'mask_word': 'girl',
#      'lemma_word': 'girl',
#      'masked_sentence': "Managed by her father, Mathew Knowles, the group became one of the world's best-selling <mask> groups of all time.",
#      'output_mask': [{'score': 0.2028,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0513, 'token': 13950, 'token_str': 'rock', 'lemma': 'rock'},
#       {'score': 0.0336,
#        'token': 82393,
#        'token_str': 'dance',
#        'lemma': 'dance'},
#       {'score': 0.0228, 'token': 12877, 'token_str': 'book', 'lemma': 'book'},
#       {'score': 0.0219,
#        'token': 108171,
#        'token_str': 'vocal',
#        'lemma': 'vocal'},
#       {'score': 0.0211,
#        'token': 24668,
#        'token_str': 'musical',
#        'lemma': 'musical'},
#       {'score': 0.0173, 'token': 8753, 'token_str': 'band', 'lemma': 'band'},
#       {'score': 0.0171,
#        'token': 180327,
#        'token_str': 'comedy',
#        'lemma': 'comedy'},
#       {'score': 0.015, 'token': 29892, 'token_str': 'rap', 'lemma': 'rap'},
#       {'score': 0.0144,
#        'token': 1431,
#        'token_str': 'Facebook',
#        'lemma': 'Facebook'}]},
#     {'mask_word': 'groups',
#      'lemma_word': 'group',
#      'masked_sentence': "Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl <mask> of all time.",
#      'output_mask': [{'score': 0.5695,
#        'token': 94407,
#        'token_str': 'groups',
#        'lemma': 'group'},
#       {'score': 0.1868, 'token': 8753, 'token_str': 'band', 'lemma': 'band'},
#       {'score': 0.059, 'token': 8262, 'token_str': 'band', 'lemma': 'of'},
#       {'score': 0.0419, 'token': 45831, 'token_str': 'shows', 'lemma': 'show'},
#       {'score': 0.0214,
#        'token': 21115,
#        'token_str': 'group',
#        'lemma': 'group'},
#       {'score': 0.015, 'token': 117406, 'token_str': 'clubs', 'lemma': 'club'},
#       {'score': 0.0118,
#        'token': 36549,
#        'token_str': 'series',
#        'lemma': 'series'},
#       {'score': 0.0108, 'token': 3387, 'token_str': 'ies', 'lemma': 'of'},
#       {'score': 0.0078,
#        'token': 43515,
#        'token_str': 'stories',
#        'lemma': 'story'},
#       {'score': 0.0073,
#        'token': 42840,
#        'token_str': 'books',
#        'lemma': 'book'}]},
#     {'mask_word': 'time',
#      'lemma_word': 'time',
#      'masked_sentence': "Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all <mask>.",
#      'output_mask': [{'score': 0.3849,
#        'token': 1733,
#        'token_str': 'time',
#        'lemma': 'time'},
#       {'score': 0.1427, 'token': 5, 'token_str': '.', 'lemma': '..'},
#       {'score': 0.0849, 'token': 20028, 'token_str': 'times', 'lemma': 'time'},
#       {'score': 0.0699, 'token': 8562, 'token_str': 'kind', 'lemma': 'kind'},
#       {'score': 0.0579, 'token': 52895, 'token_str': 'types', 'lemma': 'type'},
#       {'score': 0.0286, 'token': 32070, 'token_str': 'age', 'lemma': 'age'},
#       {'score': 0.0271, 'token': 70, 'token_str': 'the', 'lemma': 'the'},
#       {'score': 0.0227, 'token': 13267, 'token_str': 'size', 'lemma': 'size'},
#       {'score': 0.0085,
#        'token': 90926,
#        'token_str': 'levels',
#        'lemma': 'level'},
#       {'score': 0.0084,
#        'token': 12096,
#        'token_str': 'sort',
#        'lemma': 'sort'}]}]},
#   {'sentence': 'Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#    'mask': [{'mask_word': 'hiatus',
#      'lemma_word': 'hiatus',
#      'masked_sentence': 'Their <mask> saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#      'output_mask': [{'score': 0.8264,
#        'token': 133258,
#        'token_str': 'collaboration',
#        'lemma': 'collaboration'},
#       {'score': 0.0533,
#        'token': 165410,
#        'token_str': 'partnership',
#        'lemma': 'partnership'},
#       {'score': 0.0473,
#        'token': 36272,
#        'token_str': 'success',
#        'lemma': 'success'},
#       {'score': 0.0079,
#        'token': 79825,
#        'token_str': 'efforts',
#        'lemma': 'effort'},
#       {'score': 0.0076, 'token': 4488, 'token_str': 'work', 'lemma': 'work'},
#       {'score': 0.0051,
#        'token': 80997,
#        'token_str': 'career',
#        'lemma': 'career'},
#       {'score': 0.0049,
#        'token': 76755,
#        'token_str': 'relationship',
#        'lemma': 'relationship'},
#       {'score': 0.0045,
#        'token': 120696,
#        'token_str': 'journey',
#        'lemma': 'journey'},
#       {'score': 0.0031,
#        'token': 20428,
#        'token_str': 'concert',
#        'lemma': 'concert'},
#       {'score': 0.0029,
#        'token': 34377,
#        'token_str': 'debut',
#        'lemma': 'debut'}]},
#     {'mask_word': 'release',
#      'lemma_word': 'release',
#      'masked_sentence': 'Their hiatus saw the <mask> of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#      'output_mask': [{'score': 0.9538,
#        'token': 54452,
#        'token_str': 'release',
#        'lemma': 'release'},
#       {'score': 0.0093,
#        'token': 104345,
#        'token_str': 'publication',
#        'lemma': 'publication'},
#       {'score': 0.0076,
#        'token': 83184,
#        'token_str': 'launch',
#        'lemma': 'launch'},
#       {'score': 0.0062, 'token': 36069, 'token_str': 'drop', 'lemma': 'drop'},
#       {'score': 0.0049,
#        'token': 36272,
#        'token_str': 'success',
#        'lemma': 'success'},
#       {'score': 0.0036,
#        'token': 34377,
#        'token_str': 'debut',
#        'lemma': 'debut'},
#       {'score': 0.0026, 'token': 3564, 'token_str': 'end', 'lemma': 'end'},
#       {'score': 0.0008,
#        'token': 170894,
#        'token_str': 'appearance',
#        'lemma': 'appearance'},
#       {'score': 0.0008, 'token': 11473, 'token_str': 'sale', 'lemma': 'sale'},
#       {'score': 0.0008,
#        'token': 86669,
#        'token_str': 'loss',
#        'lemma': 'loss'}]},
#     {'mask_word': 'album',
#      'lemma_word': 'album',
#      'masked_sentence': 'Their hiatus saw the release of Beyoncé\'s debut <mask>, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#      'output_mask': [{'score': 0.7032,
#        'token': 7156,
#        'token_str': 'album',
#        'lemma': 'album'},
#       {'score': 0.204,
#        'token': 11001,
#        'token_str': 'single',
#        'lemma': 'single'},
#       {'score': 0.0271, 'token': 26201, 'token_str': 'EP', 'lemma': 'EP'},
#       {'score': 0.0166, 'token': 82080, 'token_str': 'LP', 'lemma': 'LP'},
#       {'score': 0.0151, 'token': 7915, 'token_str': 'CD', 'lemma': 'CD'},
#       {'score': 0.0038, 'token': 11531, 'token_str': 'song', 'lemma': 'song'},
#       {'score': 0.0034,
#        'token': 43609,
#        'token_str': 'Single',
#        'lemma': 'Single'},
#       {'score': 0.0026,
#        'token': 28560,
#        'token_str': 'track',
#        'lemma': 'track'},
#       {'score': 0.0022,
#        'token': 17164,
#        'token_str': 'record',
#        'lemma': 'record'},
#       {'score': 0.0017,
#        'token': 37340,
#        'token_str': 'Album',
#        'lemma': 'Album'}]},
#     {'mask_word': 'solo',
#      'lemma_word': 'solo',
#      'masked_sentence': 'Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a <mask> artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#      'output_mask': [{'score': 0.1168,
#        'token': 5700,
#        'token_str': 'popular',
#        'lemma': 'popular'},
#       {'score': 0.1086,
#        'token': 105207,
#        'token_str': 'leading',
#        'lemma': 'lead'},
#       {'score': 0.1032, 'token': 2639, 'token_str': 'solo', 'lemma': 'solo'},
#       {'score': 0.0813,
#        'token': 13036,
#        'token_str': 'major',
#        'lemma': 'major'},
#       {'score': 0.0762, 'token': 7426, 'token_str': 'pop', 'lemma': 'pop'},
#       {'score': 0.0483, 'token': 5962, 'token_str': 'hit', 'lemma': 'hit'},
#       {'score': 0.0253, 'token': 58984, 'token_str': 'cult', 'lemma': 'cult'},
#       {'score': 0.025, 'token': 34377, 'token_str': 'debut', 'lemma': 'debut'},
#       {'score': 0.0233,
#        'token': 182304,
#        'token_str': 'recording',
#        'lemma': 'recording'},
#       {'score': 0.0226,
#        'token': 51529,
#        'token_str': 'known',
#        'lemma': 'know'}]},
#     {'mask_word': 'artist',
#      'lemma_word': 'artist',
#      'masked_sentence': 'Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo <mask> worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".',
#      'output_mask': [{'score': 0.6338,
#        'token': 22104,
#        'token_str': 'artist',
#        'lemma': 'artist'},
#       {'score': 0.1639, 'token': 6057, 'token_str': 'star', 'lemma': 'star'},
#       {'score': 0.0467, 'token': 47989, 'token_str': 'icon', 'lemma': 'icon'},
#       {'score': 0.0216,
#        'token': 129357,
#        'token_str': 'sensation',
#        'lemma': 'sensation'},
#       {'score': 0.0144, 'token': 23040, 'token_str': 'girl', 'lemma': 'girl'},
#       {'score': 0.0118,
#        'token': 1419,
#        'token_str': 'ist',
#        'lemma': 'worldwide'},
#       {'score': 0.0083, 'token': 27992, 'token_str': 'act', 'lemma': 'act'},
#       {'score': 0.0078,
#        'token': 5613,
#        'token_str': 'star',
#        'lemma': 'worldwide'},
#       {'score': 0.0064, 'token': 5962, 'token_str': 'hit', 'lemma': 'hit'},
#       {'score': 0.0056,
#        'token': 3299,
#        'token_str': 'model',
#        'lemma': 'model'}]},
#     {'mask_word': 'number',
#      'lemma_word': 'number',
#      'masked_sentence': 'Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 <mask>-one singles "Crazy in Love" and "Baby Boy".',
#      'output_mask': [{'score': 0.347,
#        'token': 14012,
#        'token_str': 'number',
#        'lemma': 'number'},
#       {'score': 0.1733, 'token': 5962, 'token_str': 'hit', 'lemma': 'hit'},
#       {'score': 0.0722, 'token': 110, 'token_str': 'no', 'lemma': 'no'},
#       {'score': 0.0408, 'token': 1632, 'token_str': 'one', 'lemma': 'one'},
#       {'score': 0.0348,
#        'token': 11001,
#        'token_str': 'single',
#        'lemma': 'single'},
#       {'score': 0.0277, 'token': 438, 'token_str': 'No', 'lemma': 'no'},
#       {'score': 0.0218,
#        'token': 214075,
#        'token_str': 'twenty',
#        'lemma': 'twenty'},
#       {'score': 0.0186, 'token': 756, 'token_str': 'all', 'lemma': 'all'},
#       {'score': 0.0119, 'token': 6626, 'token_str': 'two', 'lemma': 'two'},
#       {'score': 0.0098,
#        'token': 3164,
#        'token_str': 'All',
#        'lemma': 'all'}]}]}],
#  [{'sentence': 'Following the disbandment of Destiny\'s Child in June 2005, she released her second solo album, B\'Day (2006), which contained hits "Déjà Vu", "Irreplaceable", and "Beautiful Liar".',
#    'mask': [{'mask_word': 'Child',
#      'lemma_word': 'child',
#      'masked_sentence': 'Following the disbandment of Destiny\'s <mask> in June 2005, she released her second solo album, B\'Day (2006), which contained hits "Déjà Vu", "Irreplaceable", and "Beautiful Liar".',
#      'output_mask': [{'score': 0.3286,
#        'token': 123829,
#        'token_str': 'Child',
#        'lemma': 'child'},
#       {'score': 0.0363,
#        'token': 183672,
#        'token_str': 'Creed',
#        'lemma': 'Creed'},
#       {'score': 0.0291, 'token': 44816, 'token_str': 'Head', 'lemma': 'Head'},
#       {'score': 0.0277, 'token': 14298, 'token_str': 'Band', 'lemma': 'Band'},
#       {'score': 0.0224, 'token': 6661, 'token_str': 'World', 'lemma': 'World'},
#       {'score': 0.0203, 'token': 7687, 'token_str': 'Club', 'lemma': 'Club'},
#       {'score': 0.0115,
#        'token': 14449,
#        'token_str': 'family',
#        'lemma': 'family'},
#       {'score': 0.0113, 'token': 116, 'token_str': '2', 'lemma': '2'},
#       {'score': 0.0112, 'token': 8753, 'token_str': 'band', 'lemma': 'band'},
#       {'score': 0.0107, 'token': 10013, 'token_str': 'Day', 'lemma': 'day'}]},
#     {'mask_word': 'solo',
#      'lemma_word': 'solo',
#      'masked_sentence': 'Following the disbandment of Destiny\'s Child in June 2005, she released her second <mask> album, B\'Day (2006), which contained hits "Déjà Vu", "Irreplaceable", and "Beautiful Liar".',
#      'output_mask': [{'score': 0.4768,
#        'token': 12275,
#        'token_str': 'studio',
#        'lemma': 'studio'},
#       {'score': 0.4726, 'token': 2639, 'token_str': 'solo', 'lemma': 'solo'},
#       {'score': 0.0099,
#        'token': 34377,
#        'token_str': 'debut',
#        'lemma': 'debut'},
#       {'score': 0.0047,
#        'token': 41929,
#        'token_str': 'double',
#        'lemma': 'double'},
#       {'score': 0.0043, 'token': 4393, 'token_str': 'full', 'lemma': 'full'},
#       {'score': 0.0035,
#        'token': 11001,
#        'token_str': 'single',
#        'lemma': 'single'},
#       {'score': 0.0027, 'token': 5962, 'token_str': 'hit', 'lemma': 'hit'},
#       {'score': 0.0024, 'token': 6867, 'token_str': 'live', 'lemma': 'live'},
#       {'score': 0.0013,
#        'token': 60213,
#        'token_str': 'feature',
#        'lemma': 'feature'},
#       {'score': 0.0013,
#        'token': 28560,
#        'token_str': 'track',
#        'lemma': 'track'}]},
#     {'mask_word': 'album',
#      'lemma_word': 'album',
#      'masked_sentence': 'Following the disbandment of Destiny\'s Child in June 2005, she released her second solo <mask>, B\'Day (2006), which contained hits "Déjà Vu", "Irreplaceable", and "Beautiful Liar".',
#      'output_mask': [{'score': 0.8896,
#        'token': 7156,
#        'token_str': 'album',
#        'lemma': 'album'},
#       {'score': 0.0681,
#        'token': 11001,
#        'token_str': 'single',
#        'lemma': 'single'},
#       {'score': 0.0134, 'token': 26201, 'token_str': 'EP', 'lemma': 'EP'},
#       {'score': 0.0044, 'token': 7915, 'token_str': 'CD', 'lemma': 'cd'},
#       {'score': 0.0039, 'token': 82080, 'token_str': 'LP', 'lemma': 'LP'},
#       {'score': 0.0026, 'token': 56329, 'token_str': 'cd', 'lemma': 'cd'},
#       {'score': 0.0024, 'token': 54981, 'token_str': 'album', 'lemma': ','},
#       {'score': 0.0019,
#        'token': 28560,
#        'token_str': 'track',
#        'lemma': 'track'},
#       {'score': 0.0016,
#        'token': 17164,
#        'token_str': 'record',
#        'lemma': 'record'},
#       {'score': 0.0015, 'token': 5962, 'token_str': 'hit', 'lemma': 'hit'}]}]},
#   {'sentence': 'Beyoncé also ventured into acting, with a Golden Globe-nominated performance in Dreamgirls (2006), and starring roles in The Pink Panther (2006) and Obsessed (2009).',
#    'mask': [{'mask_word': 'acting',
#      'lemma_word': 'acting',
#      'masked_sentence': 'Beyoncé also ventured into <mask>, with a Golden Globe-nominated performance in Dreamgirls (2006), and starring roles in The Pink Panther (2006) and Obsessed (2009).',
#      'output_mask': [{'score': 0.4746,
#        'token': 38436,
#        'token_str': 'Hollywood',
#        'lemma': 'Hollywood'},
#       {'score': 0.0696,
#        'token': 27076,
#        'token_str': 'cinema',
#        'lemma': 'cinema'},
#       {'score': 0.0624,
#        'token': 197489,
#        'token_str': 'showbiz',
#        'lemma': 'showbiz'},
#       {'score': 0.0354,
#        'token': 180327,
#        'token_str': 'comedy',
#        'lemma': 'comedy'},
#       {'score': 0.0323,
#        'token': 23134,
#        'token_str': 'drama',
#        'lemma': 'drama'},
#       {'score': 0.0309,
#        'token': 113976,
#        'token_str': 'television',
#        'lemma': 'television'},
#       {'score': 0.0252, 'token': 65536, 'token_str': 'fame', 'lemma': 'fame'},
#       {'score': 0.0251,
#        'token': 143554,
#        'token_str': 'Bollywood',
#        'lemma': 'Bollywood'},
#       {'score': 0.0194,
#        'token': 141778,
#        'token_str': 'entertainment',
#        'lemma': 'entertainment'},
#       {'score': 0.0152,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'}]},
#     {'mask_word': 'performance',
#      'lemma_word': 'performance',
#      'masked_sentence': 'Beyoncé also ventured into acting, with a Golden Globe-nominated <mask> in Dreamgirls (2006), and starring roles in The Pink Panther (2006) and Obsessed (2009).',
#      'output_mask': [{'score': 0.6163,
#        'token': 31486,
#        'token_str': 'role',
#        'lemma': 'role'},
#       {'score': 0.2219,
#        'token': 170894,
#        'token_str': 'appearance',
#        'lemma': 'appearance'},
#       {'score': 0.0905,
#        'token': 23718,
#        'token_str': 'performance',
#        'lemma': 'performance'},
#       {'score': 0.0125, 'token': 37702, 'token_str': 'cast', 'lemma': 'cast'},
#       {'score': 0.0079,
#        'token': 80997,
#        'token_str': 'career',
#        'lemma': 'career'},
#       {'score': 0.0053, 'token': 6057, 'token_str': 'star', 'lemma': 'star'},
#       {'score': 0.0048, 'token': 11301, 'token_str': 'play', 'lemma': 'play'},
#       {'score': 0.0042,
#        'token': 34377,
#        'token_str': 'debut',
#        'lemma': 'debut'},
#       {'score': 0.0039, 'token': 13162, 'token_str': 'spot', 'lemma': 'spot'},
#       {'score': 0.0032,
#        'token': 60213,
#        'token_str': 'feature',
#        'lemma': 'feature'}]},
#     {'mask_word': 'roles',
#      'lemma_word': 'role',
#      'masked_sentence': 'Beyoncé also ventured into acting, with a Golden Globe-nominated performance in Dreamgirls (2006), and starring <mask> in The Pink Panther (2006) and Obsessed (2009).',
#      'output_mask': [{'score': 0.2653,
#        'token': 25842,
#        'token_str': 'together',
#        'lemma': 'together'},
#       {'score': 0.1001,
#        'token': 13438,
#        'token_str': 'again',
#        'lemma': 'again'},
#       {'score': 0.0872, 'token': 4420, 'token_str': 'back', 'lemma': 'back'},
#       {'score': 0.0674,
#        'token': 186351,
#        'token_str': 'twice',
#        'lemma': 'twice'},
#       {'score': 0.0605,
#        'token': 121399,
#        'token_str': 'guest',
#        'lemma': 'guest'},
#       {'score': 0.0299, 'token': 2639, 'token_str': 'solo', 'lemma': 'solo'},
#       {'score': 0.026, 'token': 33233, 'token_str': 'along', 'lemma': 'along'},
#       {'score': 0.0235,
#        'token': 186085,
#        'token_str': 'regularly',
#        'lemma': 'regularly'},
#       {'score': 0.0216, 'token': 2843, 'token_str': 'also', 'lemma': 'also'},
#       {'score': 0.0209,
#        'token': 31486,
#        'token_str': 'role',
#        'lemma': 'role'}]}]},
#   {'sentence': 'Her marriage to rapper Jay Z and portrayal of Etta James in Cadillac Records (2008) influenced her third album, I Am...',
#    'mask': [{'mask_word': 'marriage',
#      'lemma_word': 'marriage',
#      'masked_sentence': 'Her <mask> to rapper Jay Z and portrayal of Etta James in Cadillac Records (2008) influenced her third album, I Am...',
#      'output_mask': [{'score': 0.4296,
#        'token': 94878,
#        'token_str': 'connection',
#        'lemma': 'connection'},
#       {'score': 0.1018,
#        'token': 76755,
#        'token_str': 'relationship',
#        'lemma': 'relationship'},
#       {'score': 0.0661,
#        'token': 41911,
#        'token_str': 'relation',
#        'lemma': 'relation'},
#       {'score': 0.053,
#        'token': 197826,
#        'token_str': 'exposure',
#        'lemma': 'exposure'},
#       {'score': 0.0366,
#        'token': 129570,
#        'token_str': 'marriage',
#        'lemma': 'marriage'},
#       {'score': 0.032,
#        'token': 132539,
#        'token_str': 'reaction',
#        'lemma': 'reaction'},
#       {'score': 0.0302,
#        'token': 91067,
#        'token_str': 'reference',
#        'lemma': 'reference'},
#       {'score': 0.0213,
#        'token': 166794,
#        'token_str': 'commitment',
#        'lemma': 'commitment'},
#       {'score': 0.015, 'token': 5161, 'token_str': 'love', 'lemma': 'love'},
#       {'score': 0.0102,
#        'token': 19922,
#        'token_str': 'visit',
#        'lemma': 'visit'}]},
#     {'mask_word': 'portrayal',
#      'lemma_word': 'portrayal',
#      'masked_sentence': 'Her marriage to rapper Jay Z and <mask> of Etta James in Cadillac Records (2008) influenced her third album, I Am...',
#      'output_mask': [{'score': 0.1012,
#        'token': 47219,
#        'token_str': 'death',
#        'lemma': 'death'},
#       {'score': 0.0813,
#        'token': 59038,
#        'token_str': 'purchase',
#        'lemma': 'purchase'},
#       {'score': 0.0722,
#        'token': 36049,
#        'token_str': 'production',
#        'lemma': 'production'},
#       {'score': 0.0712,
#        'token': 108558,
#        'token_str': 'producer',
#        'lemma': 'producer'},
#       {'score': 0.0351, 'token': 450, 'token_str': 'that', 'lemma': 'that'},
#       {'score': 0.0217,
#        'token': 54452,
#        'token_str': 'release',
#        'lemma': 'release'},
#       {'score': 0.0215,
#        'token': 166635,
#        'token_str': 'creation',
#        'lemma': 'creation'},
#       {'score': 0.0188,
#        'token': 67373,
#        'token_str': 'father',
#        'lemma': 'father'},
#       {'score': 0.0169,
#        'token': 42732,
#        'token_str': 'mother',
#        'lemma': 'mother'},
#       {'score': 0.0167,
#        'token': 82641,
#        'token_str': 'promotion',
#        'lemma': 'promotion'}]},
#     {'mask_word': 'album',
#      'lemma_word': 'album',
#      'masked_sentence': 'Her marriage to rapper Jay Z and portrayal of Etta James in Cadillac Records (2008) influenced her third <mask>, I Am...',
#      'output_mask': [{'score': 0.5907,
#        'token': 7156,
#        'token_str': 'album',
#        'lemma': 'album'},
#       {'score': 0.208,
#        'token': 11001,
#        'token_str': 'single',
#        'lemma': 'single'},
#       {'score': 0.0469, 'token': 1346, 'token_str': 'film', 'lemma': 'film'},
#       {'score': 0.0298, 'token': 11531, 'token_str': 'song', 'lemma': 'song'},
#       {'score': 0.0222, 'token': 12877, 'token_str': 'book', 'lemma': 'book'},
#       {'score': 0.0181,
#        'token': 14277,
#        'token_str': 'movie',
#        'lemma': 'movie'},
#       {'score': 0.0115,
#        'token': 21261,
#        'token_str': 'novel',
#        'lemma': 'novel'},
#       {'score': 0.004,
#        'token': 43609,
#        'token_str': 'Single',
#        'lemma': 'Single'},
#       {'score': 0.004, 'token': 17116, 'token_str': 'disc', 'lemma': 'disc'},
#       {'score': 0.0037,
#        'token': 37340,
#        'token_str': 'Album',
#        'lemma': 'Album'}]}]},
#   {'sentence': 'Sasha Fierce (2008), which saw the birth of her alter-ego Sasha Fierce and earned a record-setting six Grammy Awards in 2010, including Song of the Year for "Single Ladies (Put a Ring on It)".',
#    'mask': [{'mask_word': 'birth',
#      'lemma_word': 'birth',
#      'masked_sentence': 'Sasha Fierce (2008), which saw the <mask> of her alter-ego Sasha Fierce and earned a record-setting six Grammy Awards in 2010, including Song of the Year for "Single Ladies (Put a Ring on It)".',
#      'output_mask': [{'score': 0.143,
#        'token': 47219,
#        'token_str': 'death',
#        'lemma': 'death'},
#       {'score': 0.1035,
#        'token': 36272,
#        'token_str': 'success',
#        'lemma': 'success'},
#       {'score': 0.0613,
#        'token': 30646,
#        'token_str': 'return',
#        'lemma': 'return'},
#       {'score': 0.0575,
#        'token': 170894,
#        'token_str': 'appearance',
#        'lemma': 'appearance'},
#       {'score': 0.0312, 'token': 31486, 'token_str': 'role', 'lemma': 'role'},
#       {'score': 0.0283, 'token': 6817, 'token_str': 'fall', 'lemma': 'fall'},
#       {'score': 0.0253,
#        'token': 131527,
#        'token_str': 'exception',
#        'lemma': 'exception'},
#       {'score': 0.0233,
#        'token': 23718,
#        'token_str': 'performance',
#        'lemma': 'performance'},
#       {'score': 0.023,
#        'token': 54452,
#        'token_str': 'release',
#        'lemma': 'release'},
#       {'score': 0.0222, 'token': 46223, 'token_str': 'eyes', 'lemma': 'eye'}]},
#     {'mask_word': 'alter',
#      'lemma_word': 'alter',
# ...
#       {'score': 0.0241, 'token': 6264, 'token_str': 'opera', 'lemma': 'opera'},
#       {'score': 0.0206, 'token': 4488, 'token_str': 'work', 'lemma': 'work'},
#       {'score': 0.0205,
#        'token': 82393,
#        'token_str': 'dance',
#        'lemma': 'dance'}]},
#     {'mask_word': 'invitation',
#      'lemma_word': 'invitation',
#      'masked_sentence': 'The success of this concert led to an <mask> to give a similar recital on the instrument before Tsar Alexander I, who was visiting Warsaw; the Tsar presented him with a diamond ring.',
#      'output_mask': [{'score': 0.6056,
#        'token': 194134,
#        'token_str': 'invitation',
#        'lemma': 'invitation'},
#       {'score': 0.1045,
#        'token': 12989,
#        'token_str': 'order',
#        'lemma': 'order'},
#       {'score': 0.0843,
#        'token': 81887,
#        'token_str': 'attempt',
#        'lemma': 'attempt'},
#       {'score': 0.0406,
#        'token': 106689,
#        'token_str': 'agreement',
#        'lemma': 'agreement'},
#       {'score': 0.029,
#        'token': 54591,
#        'token_str': 'opportunity',
#        'lemma': 'opportunity'},
#       {'score': 0.0242,
#        'token': 91177,
#        'token_str': 'intention',
#        'lemma': 'intention'},
#       {'score': 0.0208, 'token': 6528, 'token_str': 'idea', 'lemma': 'idea'},
#       {'score': 0.014,
#        'token': 78091,
#        'token_str': 'intent',
#        'lemma': 'intent'},
#       {'score': 0.0114,
#        'token': 71834,
#        'token_str': 'effort',
#        'lemma': 'effort'},
#       {'score': 0.0067,
#        'token': 70767,
#        'token_str': 'arrangement',
#        'lemma': 'arrangement'}]},
#     {'mask_word': 'recital',
#      'lemma_word': 'recital',
#      'masked_sentence': 'The success of this concert led to an invitation to give a similar <mask> on the instrument before Tsar Alexander I, who was visiting Warsaw; the Tsar presented him with a diamond ring.',
#      'output_mask': [{'score': 0.5235,
#        'token': 23718,
#        'token_str': 'performance',
#        'lemma': 'performance'},
#       {'score': 0.0524,
#        'token': 116483,
#        'token_str': 'speech',
#        'lemma': 'speech'},
#       {'score': 0.0492,
#        'token': 92252,
#        'token_str': 'presentation',
#        'lemma': 'presentation'},
#       {'score': 0.0414,
#        'token': 170894,
#        'token_str': 'appearance',
#        'lemma': 'appearance'},
#       {'score': 0.0405,
#        'token': 20428,
#        'token_str': 'concert',
#        'lemma': 'concert'},
#       {'score': 0.0311,
#        'token': 59619,
#        'token_str': 'lecture',
#        'lemma': 'lecture'},
#       {'score': 0.0301, 'token': 22120, 'token_str': 'talk', 'lemma': 'talk'},
#       {'score': 0.0174, 'token': 11301, 'token_str': 'play', 'lemma': 'play'},
#       {'score': 0.0157,
#        'token': 4516,
#        'token_str': 'service',
#        'lemma': 'service'},
#       {'score': 0.0149,
#        'token': 75544,
#        'token_str': 'concerto',
#        'lemma': 'concerto'}]},
#     {'mask_word': 'instrument',
#      'lemma_word': 'instrument',
#      'masked_sentence': 'The success of this concert led to an invitation to give a similar recital on the <mask> before Tsar Alexander I, who was visiting Warsaw; the Tsar presented him with a diamond ring.',
#      'output_mask': [{'score': 0.3179,
#        'token': 17431,
#        'token_str': 'night',
#        'lemma': 'night'},
#       {'score': 0.2839, 'token': 5155, 'token_str': 'day', 'lemma': 'day'},
#       {'score': 0.0992,
#        'token': 105216,
#        'token_str': 'evening',
#        'lemma': 'evening'},
#       {'score': 0.0597,
#        'token': 46505,
#        'token_str': 'occasion',
#        'lemma': 'occasion'},
#       {'score': 0.0378, 'token': 13312, 'token_str': 'days', 'lemma': 'day'},
#       {'score': 0.0259, 'token': 5622, 'token_str': 'date', 'lemma': 'date'},
#       {'score': 0.0147,
#        'token': 52305,
#        'token_str': 'Sunday',
#        'lemma': 'Sunday'},
#       {'score': 0.0132,
#        'token': 157109,
#        'token_str': 'afternoon',
#        'lemma': 'afternoon'},
#       {'score': 0.009, 'token': 10013, 'token_str': 'Day', 'lemma': 'day'},
#       {'score': 0.0084,
#        'token': 72864,
#        'token_str': 'Saturday',
#        'lemma': 'Saturday'}]},
#     {'mask_word': 'diamond',
#      'lemma_word': 'diamond',
#      'masked_sentence': 'The success of this concert led to an invitation to give a similar recital on the instrument before Tsar Alexander I, who was visiting Warsaw; the Tsar presented him with a <mask> ring.',
#      'output_mask': [{'score': 0.29,
#        'token': 158044,
#        'token_str': 'golden',
#        'lemma': 'golden'},
#       {'score': 0.0758,
#        'token': 115392,
#        'token_str': 'silver',
#        'lemma': 'silver'},
#       {'score': 0.033, 'token': 86761, 'token_str': 'gold', 'lemma': 'gold'},
#       {'score': 0.0317,
#        'token': 81141,
#        'token_str': 'wedding',
#        'lemma': 'wedding'},
#       {'score': 0.0204,
#        'token': 34923,
#        'token_str': 'beautiful',
#        'lemma': 'beautiful'},
#       {'score': 0.0172, 'token': 3525, 'token_str': 'new', 'lemma': 'new'},
#       {'score': 0.0136,
#        'token': 49846,
#        'token_str': 'magic',
#        'lemma': 'magic'},
#       {'score': 0.0088,
#        'token': 47589,
#        'token_str': 'glass',
#        'lemma': 'glass'},
#       {'score': 0.0085,
#        'token': 5361,
#        'token_str': 'special',
#        'lemma': 'special'},
#       {'score': 0.0075,
#        'token': 19336,
#        'token_str': 'small',
#        'lemma': 'small'}]},
#     {'mask_word': 'ring',
#      'lemma_word': 'ring',
#      'masked_sentence': 'The success of this concert led to an invitation to give a similar recital on the instrument before Tsar Alexander I, who was visiting Warsaw; the Tsar presented him with a diamond <mask>.',
#      'output_mask': [{'score': 0.0868,
#        'token': 15789,
#        'token_str': 'ring',
#        'lemma': 'ring'},
#       {'score': 0.0737,
#        'token': 122360,
#        'token_str': 'ornament',
#        'lemma': 'ornament'},
#       {'score': 0.0637,
#        'token': 24320,
#        'token_str': 'pendant',
#        'lemma': 'pendant'},
#       {'score': 0.0611, 'token': 5, 'token_str': '.', 'lemma': '..'},
#       {'score': 0.0557,
#        'token': 232070,
#        'token_str': 'bracelet',
#        'lemma': 'bracelet'},
#       {'score': 0.0219,
#        'token': 178829,
#        'token_str': 'painting',
#        'lemma': 'painting'},
#       {'score': 0.0211,
#        'token': 44116,
#        'token_str': 'display',
#        'lemma': 'display'},
#       {'score': 0.0207, 'token': 112239, 'token_str': 'vase', 'lemma': 'vase'},
#       {'score': 0.0191,
#        'token': 13984,
#        'token_str': 'instrument',
#        'lemma': 'instrument'},
#       {'score': 0.0146,
#        'token': 40501,
#        'token_str': 'medal',
#        'lemma': 'medal'}]}]},
#   {'sentence': 'At a subsequent eolomelodicon concert on 10 June 1825, Chopin performed his Rondo Op.',
#    'mask': [{'mask_word': 'eolomelodicon',
#      'lemma_word': 'eolomelodicon',
#      'masked_sentence': 'At a subsequent <mask> concert on 10 June 1825, Chopin performed his Rondo Op.',
#      'output_mask': [{'score': 0.0804,
#        'token': 7270,
#        'token_str': 'Paris',
#        'lemma': 'Paris'},
#       {'score': 0.056,
#        'token': 3835,
#        'token_str': 'public',
#        'lemma': 'public'},
#       {'score': 0.0483, 'token': 2639, 'token_str': 'solo', 'lemma': 'solo'},
#       {'score': 0.0367,
#        'token': 199506,
#        'token_str': 'Broadway',
#        'lemma': 'Broadway'},
#       {'score': 0.0287,
#        'token': 14375,
#        'token_str': 'private',
#        'lemma': 'private'},
#       {'score': 0.0244,
#        'token': 20428,
#        'token_str': 'concert',
#        'lemma': 'concert'},
#       {'score': 0.024, 'token': 16569, 'token_str': 'piano', 'lemma': 'piano'},
#       {'score': 0.0237,
#        'token': 9020,
#        'token_str': 'London',
#        'lemma': 'London'},
#       {'score': 0.0196,
#        'token': 40111,
#        'token_str': 'Christmas',
#        'lemma': 'Christmas'},
#       {'score': 0.0192, 'token': 6867, 'token_str': 'live', 'lemma': 'live'}]},
#     {'mask_word': 'concert',
#      'lemma_word': 'concert',
#      'masked_sentence': 'At a subsequent eolomelodicon <mask> on 10 June 1825, Chopin performed his Rondo Op.',
#      'output_mask': [{'score': 0.7146,
#        'token': 4,
#        'token_str': ',',
#        'lemma': ','},
#       {'score': 0.0635,
#        'token': 20428,
#        'token_str': 'concert',
#        'lemma': 'concert'},
#       {'score': 0.0223,
#        'token': 8395,
#        'token_str': 'festival',
#        'lemma': 'festival'},
#       {'score': 0.0215, 'token': 34658, 'token_str': 'held', 'lemma': 'hold'},
#       {'score': 0.0155,
#        'token': 56002,
#        'token_str': 'session',
#        'lemma': 'session'},
#       {'score': 0.0116, 'token': 7639, 'token_str': 'show', 'lemma': 'show'},
#       {'score': 0.0112,
#        'token': 23718,
#        'token_str': 'performance',
#        'lemma': 'performance'},
#       {'score': 0.0083,
#        'token': 19732,
#        'token_str': 'event',
#        'lemma': 'event'},
#       {'score': 0.0068,
#        'token': 19085,
#        'token_str': 'party',
#        'lemma': 'party'},
#       {'score': 0.0058,
#        'token': 108870,
#        'token_str': 'conference',
#        'lemma': 'conference'}]}]},
#   {'sentence': '1.', 'mask': []},
#   {'sentence': 'This was the first of his works to be commercially published and earned him his first mention in the foreign press, when the Leipzig Allgemeine Musikalische Zeitung praised his "wealth of musical ideas".',
#    'mask': [{'mask_word': 'works',
#      'lemma_word': 'work',
#      'masked_sentence': 'This was the first of his <mask> to be commercially published and earned him his first mention in the foreign press, when the Leipzig Allgemeine Musikalische Zeitung praised his "wealth of musical ideas".',
#      'output_mask': [{'score': 0.7628,
#        'token': 43240,
#        'token_str': 'works',
#        'lemma': 'work'},
#       {'score': 0.1102, 'token': 4488, 'token_str': 'work', 'lemma': 'work'},
#       {'score': 0.0551, 'token': 52336, 'token_str': 'songs', 'lemma': 'song'},
#       {'score': 0.0128, 'token': 42840, 'token_str': 'books', 'lemma': 'book'},
#       {'score': 0.0094,
#        'token': 126371,
#        'token_str': 'pieces',
#        'lemma': 'piece'},
#       {'score': 0.0092,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0041, 'token': 54180, 'token_str': 'films', 'lemma': 'film'},
#       {'score': 0.0034,
#        'token': 77635,
#        'token_str': 'projects',
#        'lemma': 'project'},
#       {'score': 0.0032, 'token': 25647, 'token_str': 'ideas', 'lemma': 'idea'},
#       {'score': 0.002,
#        'token': 6264,
#        'token_str': 'opera',
#        'lemma': 'opera'}]},
#     {'mask_word': 'mention',
#      'lemma_word': 'mention',
#      'masked_sentence': 'This was the first of his works to be commercially published and earned him his first <mask> in the foreign press, when the Leipzig Allgemeine Musikalische Zeitung praised his "wealth of musical ideas".',
#      'output_mask': [{'score': 0.1522,
#        'token': 3687,
#        'token_str': 'place',
#        'lemma': 'place'},
#       {'score': 0.0826, 'token': 9351, 'token_str': 'name', 'lemma': 'name'},
#       {'score': 0.0704, 'token': 13162, 'token_str': 'spot', 'lemma': 'spot'},
#       {'score': 0.0698,
#        'token': 41392,
#        'token_str': 'mention',
#        'lemma': 'mention'},
#       {'score': 0.0661,
#        'token': 170894,
#        'token_str': 'appearance',
#        'lemma': 'appearance'},
#       {'score': 0.0522,
#        'token': 19069,
#        'token_str': 'position',
#        'lemma': 'position'},
#       {'score': 0.0455,
#        'token': 216473,
#        'token_str': 'reputation',
#        'lemma': 'reputation'},
#       {'score': 0.0445,
#        'token': 36272,
#        'token_str': 'success',
#        'lemma': 'success'},
#       {'score': 0.034,
#        'token': 230466,
#        'token_str': 'recognition',
#        'lemma': 'recognition'},
#       {'score': 0.0261,
#        'token': 49128,
#        'token_str': 'impression',
#        'lemma': 'impression'}]},
#     {'mask_word': 'press',
#      'lemma_word': 'press',
#      'masked_sentence': 'This was the first of his works to be commercially published and earned him his first mention in the foreign <mask>, when the Leipzig Allgemeine Musikalische Zeitung praised his "wealth of musical ideas".',
#      'output_mask': [{'score': 0.3498,
#        'token': 163136,
#        'token_str': 'literature',
#        'lemma': 'literature'},
#       {'score': 0.1878,
#        'token': 24234,
#        'token_str': 'press',
#        'lemma': 'press'},
#       {'score': 0.0669,
#        'token': 2450,
#        'token_str': 'media',
#        'lemma': 'medium'},
#       {'score': 0.0537,
#        'token': 30501,
#        'token_str': 'presse',
#        'lemma': 'presse'},
#       {'score': 0.0467, 'token': 8999, 'token_str': 'world', 'lemma': 'world'},
#       {'score': 0.0379,
#        'token': 46876,
#        'token_str': 'language',
#        'lemma': 'language'},
#       {'score': 0.0174,
#        'token': 16839,
#        'token_str': 'market',
#        'lemma': 'market'},
#       {'score': 0.0127,
#        'token': 15122,
#        'token_str': 'paper',
#        'lemma': 'paper'},
#       {'score': 0.0087, 'token': 42840, 'token_str': 'books', 'lemma': 'book'},
#       {'score': 0.0083,
#        'token': 130370,
#        'token_str': 'circles',
#        'lemma': 'circle'}]},
#     {'mask_word': 'wealth',
#      'lemma_word': 'wealth',
#      'masked_sentence': 'This was the first of his works to be commercially published and earned him his first mention in the foreign press, when the Leipzig Allgemeine Musikalische Zeitung praised his "<mask> of musical ideas".',
#      'output_mask': [{'score': 0.0415,
#        'token': 60089,
#        'token_str': 'city',
#        'lemma': 'city'},
#       {'score': 0.036, 'token': 14137, 'token_str': 'book', 'lemma': 'book'},
#       {'score': 0.0336,
#        'token': 55474,
#        'token_str': 'maker',
#        'lemma': 'maker'},
#       {'score': 0.0319,
#        'token': 92105,
#        'token_str': 'fusion',
#        'lemma': 'fusion'},
#       {'score': 0.0272,
#        'token': 152667,
#        'token_str': 'piece',
#        'lemma': 'piece'},
#       {'score': 0.0253, 'token': 18244, 'token_str': 'work', 'lemma': 'work'},
#       {'score': 0.0198,
#        'token': 129857,
#        'token_str': 'storm',
#        'lemma': 'storm'},
#       {'score': 0.0193,
#        'token': 141325,
#        'token_str': 'transfer',
#        'lemma': 'transfer'},
#       {'score': 0.0168,
#        'token': 223354,
#        'token_str': 'people',
#        'lemma': 'people'},
#       {'score': 0.0133, 'token': 669, 'token_str': 'man', 'lemma': 'man'}]},
#     {'mask_word': 'ideas',
#      'lemma_word': 'idea',
#      'masked_sentence': 'This was the first of his works to be commercially published and earned him his first mention in the foreign press, when the Leipzig Allgemeine Musikalische Zeitung praised his "wealth of musical <mask>".',
#      'output_mask': [{'score': 0.165,
#        'token': 32562,
#        'token_str': 'writing',
#        'lemma': 'writing'},
#       {'score': 0.0665,
#        'token': 12348,
#        'token_str': 'talent',
#        'lemma': 'talent'},
#       {'score': 0.0478,
#        'token': 19612,
#        'token_str': 'music',
#        'lemma': 'music'},
#       {'score': 0.0435,
#        'token': 166577,
#        'token_str': 'composition',
#        'lemma': 'composition'},
#       {'score': 0.0347, 'token': 4927, 'token_str': 'art', 'lemma': 'art'},
#       {'score': 0.0281,
#        'token': 36049,
#        'token_str': 'production',
#        'lemma': 'production'},
#       {'score': 0.0243,
#        'token': 23718,
#        'token_str': 'performance',
#        'lemma': 'performance'},
#       {'score': 0.0235,
#        'token': 163136,
#        'token_str': 'literature',
#        'lemma': 'literature'},
#       {'score': 0.0232,
#        'token': 125195,
#        'token_str': 'expression',
#        'lemma': 'expression'},
#       {'score': 0.0201,
#        'token': 53019,
#        'token_str': 'education',
#        'lemma': 'education'}]}]}]]

# %%
unmasker("how are <mask>, I am really <mask> exciting !",top_k=5)

# %%
((len(paragraphs)/10)*68)/3600
# Out:
# 35.955

# %%
sen_nlp,token
# Out:
# (Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".,
#  .)

# %%
s0 =sentences[0]

# %%
token, masked_sentence
# Out:
# (group,
#  "Managed by her father, Mathew Knowles, the  <mask>  became one of the world's best-selling girl  <mask> s of all time.")

# %%
mask[1]['mask'][1]
# Out:
# {'mask_word': 'dancing',
#  'masked_sentence': "Born and raised in Houston, Texas, she performed in various singing and  <mask>  competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child.",
#  'output_mask': [{'score': 0.5852501392364502,
#    'token': 82393,
#    'token_str': 'dance',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and dance competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.035630419850349426,
#    'token': 19612,
#    'token_str': 'music',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and music competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.03368469700217247,
#    'token': 23718,
#    'token_str': 'performance',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and performance competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.028925476595759392,
#    'token': 32562,
#    'token_str': 'writing',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and writing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.0262080617249012,
#    'token': 108171,
#    'token_str': 'vocal',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and vocal competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.025751594454050064,
#    'token': 47617,
#    'token_str': 'drum',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and drum competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.02436773106455803,
#    'token': 180327,
#    'token_str': 'comedy',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and comedy competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.02345586009323597,
#    'token': 23134,
#    'token_str': 'drama',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and drama competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.016396833583712578,
#    'token': 16569,
#    'token_str': 'piano',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and piano competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."},
#   {'score': 0.013009019196033478,
#    'token': 182304,
#    'token_str': 'recording',
#    'sequence': "Born and raised in Houston, Texas, she performed in various singing and recording competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child."}]}

# %%
import spacy
from spacy.lang.en import English
from nltk.stem.porter import PorterStemmer

nlp = English()
stemmer = PorterStemmer()

def stem_tokens(tokens):
    return [stemmer.stem(token.text) for token in tokens]

doc = nlp("I am running in the park with my dogs")
tokens = doc

stemmed_tokens = stem_tokens(tokens)
print(stemmed_tokens)
# Out:
# ['i', 'am', 'run', 'in', 'the', 'park', 'with', 'my', 'dog']

# %%
stemmer.stem('run')
# Out:
# 'run'

# %%
 unmasker(mask[1],top_k=10)
# Out:
# ---------------------------------------------------------------------------
# PipelineException                         Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
# ----> 1 unmasker(mask[1],top_k=10)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/fill_mask.py:239, in FillMaskPipeline.__call__(self, inputs, *args, **kwargs)
#     217 def __call__(self, inputs, *args, **kwargs):
#     218     """
#     219     Fill the masked token in the text(s) given as inputs.
#     220
#    (...)
#     237         - **token** (`str`) -- The predicted token (to replace the masked one).
#     238     """
# --> 239     outputs = super().__call__(inputs, **kwargs)
#     240     if isinstance(inputs, list) and len(inputs) == 1:
#     241         return outputs[0]
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1109, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1101     return next(
#    1102         iter(
#    1103             self.get_iterator(
#    (...)
#    1106         )
#    1107     )
#    1108 else:
# -> 1109     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1115, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1114 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
# -> 1115     model_inputs = self.preprocess(inputs, **preprocess_params)
#    1116     model_outputs = self.forward(model_inputs, **forward_params)
#    1117     outputs = self.postprocess(model_outputs, **postprocess_params)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/fill_mask.py:97, in FillMaskPipeline.preprocess(self, inputs, return_tensors, **preprocess_parameters)
#      95     return_tensors = self.framework
#      96 model_inputs = self.tokenizer(inputs, return_tensors=return_tensors)
# ---> 97 self.ensure_exactly_one_mask_token(model_inputs)
#      98 return model_inputs
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/fill_mask.py:91, in FillMaskPipeline.ensure_exactly_one_mask_token(self, model_inputs)
#      89 else:
#      90     for input_ids in model_inputs["input_ids"]:
# ---> 91         self._ensure_exactly_one_mask_token(input_ids)
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/fill_mask.py:79, in FillMaskPipeline._ensure_exactly_one_mask_token(self, input_ids)
#      77 numel = np.prod(masked_index.shape)
#      78 if numel < 1:
# ---> 79     raise PipelineException(
#      80         "fill-mask",
#      81         self.model.base_model_prefix,
#      82         f"No mask_token ({self.tokenizer.mask_token}) found on the input",
#      83     )
#
# PipelineException: No mask_token (<mask>) found on the input

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
doc = nlp("running runs runner ran")

# %%
for token in doc:
    print(token.text, token.lemma_)
# Out:
# running run
# runs run
# runner runner
# ran run

# %%
text = 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".'

doc = nlp(text)
for token in doc:
    if token.pos_=='NOUN':
        print(token.text, token.pos_)
# Out:
# singer NOUN
# songwriter NOUN
# record NOUN
# producer NOUN
# actress NOUN
# singing NOUN
# dancing NOUN
# competitions NOUN
# child NOUN
# fame NOUN
# 1990s NOUN
# lead NOUN
# singer NOUN
# girl NOUN
# group NOUN
# Child NOUN
# father NOUN
# group NOUN
# world NOUN
# girl NOUN
# groups NOUN
# time NOUN
# hiatus NOUN
# release NOUN
# album NOUN
# solo NOUN
# artist NOUN
# number NOUN

# %%
list(doc)[0].pos_
# Out:
# 'PROPN'

# %%
paragraphs[0]
# Out:
# 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".'
